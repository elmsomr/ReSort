# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 923.8/923.8 kB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from ultralytics import YOLO

# Load a pre-trained YOLO model (adjust model type as needed)
model = YOLO("/content/drive/MyDrive/train/weights/best.pt")  # n, s, m, l, x versions available

# Perform object detection on an image
results = model.predict(source="/content/drive/MyDrive/IMG_4660.MOV", save=True)  # Can also use video, directory, URL, etc.
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/881) /content/drive/MyDrive/IMG_4660.MOV: 384x640 1 paper, 11.9ms
# video 1/1 (frame 2/881) /content/drive/MyDrive/IMG_4660.MOV: 384x640 1 paper, 10.6ms
# video 1/1 (frame 3/881) /content/drive/MyDrive/IMG_4660.MOV: 384x640 1 paper, 10.6ms
# video 1/1 (frame 4/881) /content/drive/MyDrive/IMG_4660.MOV: 384x640 1 paper, 10.4ms
# video 1/1 (frame 5/881) /content/drive/MyDrive/IMG_4660.MOV: 384x640 1 paper, 10.6ms
# ...

# %% [markdown]
# # **Burda bir dosyadaki tüm fotoğrafları tek seferde predict ediyor!!**

# %%
from ultralytics import YOLO

# Eğitilmiş modelin yolunu verin
model = YOLO("/content/drive/MyDrive/train/weights/best.pt")

# Belirtilen klasördeki tüm görüntüler üzerinde test yapar
results = model.predict(source="/content/drive/MyDrive/resimdeneme", save=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# image 1/23 /content/drive/MyDrive/resimdeneme/IMG-20250222-WA0014.jpg: 640x480 2 glasss, 88.4ms
# image 2/23 /content/drive/MyDrive/resimdeneme/IMG-20250222-WA0015.jpg: 640x480 1 plastic, 10.8ms
# image 3/23 /content/drive/MyDrive/resimdeneme/IMG-20250222-WA0016.jpg: 640x480 4 glasss, 12.7ms
# image 4/23 /content/drive/MyDrive/resimdeneme/IMG-20250222-WA0017.jpg: 640x480 4 glasss, 10.6ms
# image 5/23 /content/drive/MyDrive/resimdeneme/IMG-20250222-WA0018.jpg: 640x480 (no detections), 10.8ms
# image 6/23 /content/drive/MyDrive/resimdeneme/IMG-20250222-WA0019.jpg: 640x480 (no detections), 10.6ms
# ...

# %%
import torch

# YOLO model dosyasının yolunu belirt
# Corrected model path
model_path = "/content/drive/MyDrive/train/weights/best.pt"

# Modeli yükle
checkpoint = torch.load(model_path, map_location='cpu')

# Metadata bilgilerini ekrana yazdır
print(f"Best Model Epoch: {checkpoint['epoch']}")
print(f"Model Type: {checkpoint['model'].yaml}")
print(f"Optimizer: {checkpoint['optimizer']}")
# Out:
# Best Model Epoch: -1
# ...
